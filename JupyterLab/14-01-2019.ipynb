# %% [markdown]
# ### Tweets_DataSet available
# - ## Function in Python:-
#     - ## Built-in Function:-
#     - ## User-defined Function:-

# %% [markdown]
#  ##### -----------------------------------------------------------------------------
# - Function with no parameter return value or single  parameter return value:-

# %%
def square(value):
    cal_value= value ** 2
    return cal_value #------------> using 'return' keyword
(square(4))
# Out:
# 16

# %%
def sqr(value):
    """Retun the value of square"""
    calc_value = value ** 2
    return calc_value
sqr(5)
# Out:
# 25

# %% [markdown]
# #### ---------------------------------------------------------------------------
# - Function with multiple parameter return value:-

# %%
def double(value_1,value_2):
    """ Here the output with two parameter """
    value = value_1 ** value_2
    return (value)
print(double(3,2))
print(double(2,3))
# Out:
# 9
# 8

# %%
def double(value_1,value_2):
    """ Here the output with two parameter """
    value = value_1 ** value_2
    print(value)
(double(3,2))
double(2,3)
# Out:
# 9
# 8

# %% [markdown]
# - ## Tuple:
#      - ### Like a list- Contains multiple values
#      - ### Immutable- can't change values
#      - ### Tuple can constructed using paranthesis '( )'

# %%
even_numbers = (0,2,4,6,8,10)
print(type(even_numbers))
# Out:
# <class 'tuple'>

# %%
a,b,c,d,e,f = even_numbers
print(a)
print(b)
print(c)
print(d)
print(e)
print(f)
# Out:
# 0
# 2
# 4
# 6
# 8
# 10

# %%
trying = (2,'2.35',4)
g,h,i=trying
print(g)
print(trying[:])
print(trying[0])
print(trying[1])
type(h)
# Out:
# 2
# (2, '2.35', 4)
# 2
# 2.35
# str

# %%
def example(value_1,value_2):
    """ This is def for tuple usage example."""
    power_value_1 = value_1 ** value_2
    power_value_2 = value_2 ** value_1
    return (power_value_1,power_value_2)
example(3,2)
# Out:
# (9, 8)

# %%
def example(value_1,value_2):
    """ This is def for tuple usage example."""
    power_value_1 = value_1 ** value_2
    power_value_2 = value_2 ** value_1
    new_tuple = (power_value_1,power_value_2) # value passed using 'tuple'.
    return new_tuple # returned value using tuple.
example(3,2)
# Out:
# (9, 8)

# %%
import pandas as pd
import matplotlib.pyplot as plt
file_path = 'C:\\Users\\Family\\tweets.csv'
tweets_df = pd.read_csv(file_path)
sorted_tweets_df=tweets_df.sort_values('contributors')

# %%
sorted_tweets_df.plot()

# %%
sorted_tweets_df.plot(kind='scatter',x='timestamp_ms',y='id')

# %%
sorted_tweets_df
# Out:
#     contributors  coordinates                      created_at  \
# 0            NaN          NaN  Tue Mar 29 23:40:17 +0000 2016
# 1            NaN          NaN  Tue Mar 29 23:40:17 +0000 2016
# 2            NaN          NaN  Tue Mar 29 23:40:17 +0000 2016
# 3            NaN          NaN  Tue Mar 29 23:40:17 +0000 2016
# 4            NaN          NaN  Tue Mar 29 23:40:17 +0000 2016
# 5            NaN          NaN  Tue Mar 29 23:40:17 +0000 2016
# 6            NaN          NaN  Tue Mar 29 23:40:18 +0000 2016
# 7            NaN          NaN  Tue Mar 29 23:40:17 +0000 2016
# 8            NaN          NaN  Tue Mar 29 23:40:18 +0000 2016
# 9            NaN          NaN  Tue Mar 29 23:40:18 +0000 2016
# 10           NaN          NaN  Tue Mar 29 23:40:18 +0000 2016
# 11           NaN          NaN  Tue Mar 29 23:40:17 +0000 2016
# 12           NaN          NaN  Tue Mar 29 23:40:18 +0000 2016
# 13           NaN          NaN  Tue Mar 29 23:40:18 +0000 2016
# ...

# %% [markdown]
# - ### Instruction:-
# - -----------------------------------------------------------------------------------
#   - Great job! You've now defined the functionality for iterating over entries in a column and building a dictionary with keys the names of languages and values the number of tweets in the given language.
#
#   - In this exercise, you will define a function with the functionality you developed in the previous exercise, return the resulting dictionary from within the function, and call the function with the appropriate arguments.
#
#   - For your convenience, the pandas package has been imported as pd and the 'tweets.csv' file has been imported into the tweets_df variable.
#
# - -----------------------------------------------------------------------
# - ### Step By Step Instructions:-
# - ------------------------------------------------------------------
#    - Define the function count_entries(), which has two parameters. The first parameter is df for the DataFrame and the second  is col_name for the column name.
#    - Complete the bodies of the if-else statements in the for loop: if the key is in the dictionary langs_count, add 1 to its      current value, else add the key to langs_count and set its value to 1. Use the loop variable entry in your code.
#    - Return the langs_count dictionary from inside the count_entries() function.
#    - Call the count_entries() function by passing to it tweets_df and the name of the column, 'lang'. Assign the result of the call   to the variable result.

# %% [markdown]
# ### Define count_entries( )
# def ____(____, ____):
#     "Return a dictionary with counts of
#     occurrences as value for each key."
#
#     # Initialize an empty dictionary: langs_count
#     langs_count = {}
#
#     # Extract column from DataFrame: col
#     col = df[col_name]
#
#     # Iterate over lang column in DataFrame
#     for entry in col:
#
#         # If the language is in langs_count, add 1
#         if entry in langs_count.keys():
#             ____
#         # Else add the language to langs_count, set the value to 1
#         else:
#             ____
#
#     # Return the langs_count dictionary
#
#
# Call count_entries(): result
#
#
# Print the result
# print(result)

# %%
def count_entries(df,col_name):
    # Initialize an empty dictionary: langs_count
    lang_count={}
    
    # Extract column from DataFrame: col
    col=df[col_name]
    
    # Iterate over lang column in DataFrame
    for entry in col:
        if entry in lang_count.keys():
            lang_count[entry] += 1
        else:
            lang_count[entry] = 1
    return lang_count

# calling availabel dataFrame 'df' and col_name 'lang'
result = count_entries(tweets_df,'lang')

# printing result
print(result)
# Out:
# {'en': 97, 'et': 1, 'und': 2}

# %% [markdown]
# - ---------------------------------------------------------------------------------
# - ## Scope and User-defined function:-

# %% [markdown]
# - ## Scope: <h5>A range or limit  or part of programme where perticular <u>object</u> or <u>name</u> that can accessible.</h5>
#  - ## Local
#  - ## Global
#  - ## Bulit-in Scope

# %%
new_val = 10
def square(value):
    """ this defined function for square."""
    new_val_1 = value ** 2
    return new_val_1
print(square(20))
new_val
# Out:
# 400
# 10

# %%
new_value = 20
def sqr(value_1):
    new_value_1 = new_value ** 2
    return new_value_1
print(sqr(3))
new_value = 10
sqr(4)
# Out:
# 400
# 100

# %%
new_value = 20
def demo(value_1):
    global new_value # if user want to assign the global variable and want to change it the there must referenced as global
    new_value = new_value ** 2
    return new_value
print(demo(3))
new_value
# Out:
# 400
# 400

# %%
num = 5
def func1():
    num = 3
    print(num)
def func2():
    global num 
    double_num = num * 2
    num = 6
    print(double_num)
(func1())
(func2())
print(num)
# Out:
# 3
# 10
# 6

# %% [markdown]
# - -------------------------------------------------------------
# - ## Nested Function:-
#     - outer function also called as 'enclosing function' because it enclose the inner function

# %%
def mod2plus5(arg1,arg2,arg3):
    def inner(x):
        return x % 2 + 5
    return (inner(arg1),inner(arg2),inner(arg3))
mod2plus5(3,2,5)
# Out:
# (6, 5, 6)

# %%
# Define echo_shout()
def echo_shout(word):
    """Change the value of a nonlocal variable"""
    
    # Concatenate word with itself: echo_word
    echo_word = word * 2
    
    # Print echo_word
    print(echo_word)
    
    # Define inner function shout()
    def shout():
        """Alter a variable in the enclosing scope"""    
        # Use echo_word in nonlocal scope
        nonlocal echo_word
        
        # Change echo_word to echo_word concatenated with '!!!'
        echo_word = echo_word + '!!!'
    
    # Call function shout()
    shout()
    
    # Print echo_word
    print(echo_word)

# Call function echo_shout() with argument 'hello'
echo_shout('hello')
# Out:
# hellohello
# hellohello!!!

# %% [markdown]
# - -------------------------------------------------------------------------
# - ## Default and flexible argument:

# %%
def power(value,pow_1=3): # here we assigning the pow_1 = 3 as a default value but during calling function if we want 
    # to change it they we can.
    """ default arguments demo """
    new_value = value * pow_1
    return new_value
print(power(2))
power(2,4)
# Out:
# 6
# 8

# %%
def sum_all(*args):
    sum_all_is = 0
    for ele in args:
        sum_all_is += ele
    return sum_all_is
sum_all(10,20,30)
# Out:
# 60

# %%
print_all(name="nikhil",job="Data Scientist",location='Banglore')
# Out:
# name : nikhil
# job : Data Scientist
# location : Banglore

# %%
def print_all(**key_value):
    for key,value in key_value.items():
        print(key + ' : '+ value)

# %%
# Define shout_echo
def shout_echo(word1,echo=1,intense=False):
    """Concatenate echo copies of word1 and three
    exclamation marks at the end of the string."""

    # Concatenate echo copies of word1 using *: echo_word
    echo_word = word1 * echo

    # Capitalize echo_word if intense is True
    if intense is True:
        # Capitalize and concatenate '!!!': echo_word_new
        echo_word_new = echo_word.upper() + '!!!'
    else:
        # Concatenate '!!!' to echo_word: echo_word_new
        echo_word_new = echo_word + '!!!'

    # Return echo_word_new
    return echo_word_new

# Call shout_echo() with "Hey", echo=5 and intense=True: with_big_echo
with_big_echo = shout_echo("Hey",5,True)

# Call shout_echo() with "Hey" and intense=True: big_no_echo
big_no_echo = shout_echo("Hey",1,True)

# Print values
print(with_big_echo)
print(big_no_echo)
# Out:
# HEYHEYHEYHEYHEY!!!
# HEY!!!

# %%
# Define gibberish
def gibberish(*args):
    """Concatenate strings in *args together."""

    # Initialize an empty string: hodgepodge
    hodgepodge = ''

    # Concatenate the strings in args
    for word in args:
        hodgepodge += word

    # Return hodgepodge
    return hodgepodge

# Call gibberish() with one string: one_word
one_word = gibberish("luke")

# Call gibberish() with five strings: many_words
many_words = gibberish("luke", "leia", "han", "obi", "darth")

# Print one_word and many_words
print(one_word)
print(many_words)
# Out:
# luke
# lukeleiahanobidarth

# %%
# Define report_status
def report_status(**kwargs):
    """Print out the status of a movie character."""

    print("\nBEGIN: REPORT\n")

    # Iterate over the key-value pairs of kwargs
    for key, value in kwargs.items():
        # Print out the keys and values, separated by a colon ':'
        print(key + ": " + value)

    print("\nEND REPORT")

# First call to report_status()
report_status(name='Nikhil', affiliation='Sangali', status='has lost')

# Second call to report_status()
report_status(name='anakin', affiliation='sith lord', status='deceased')
# Out:
# BEGIN: REPORT
#
# name: Nikhil
# affiliation: Sangali
# status: has lost
#
# END REPORT
#
# BEGIN: REPORT
#
# name: anakin
# affiliation: sith lord
# status: deceased
#
# END REPORT

# %%
# Define count_entries()
def count_entries(df,col_name='lang'):
    """Return a dictionary with counts of
    occurrences as value for each key."""

    # Initialize an empty dictionary: cols_count
    cols_count = {}

    # Extract column from DataFrame: col
    col = df[col_name]
    
    # Iterate over the column in DataFrame
    for entry in col:

        # If entry is in cols_count, add 1
        if entry in cols_count.keys():
            cols_count[entry] += 1

        # Else add the entry to cols_count, set the value to 1
        else:
            cols_count[entry] = 1

    # Return the cols_count dictionary
    return cols_count

# Call count_entries(): result1
result1 = count_entries(tweets_df)

# Call count_entries(): result2
result2 = count_entries(tweets_df,'source')

# Print result1 and result2
print(result1)
print(result2)
# Out:
# {'en': 97, 'et': 1, 'und': 2}
# {'<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>': 24, '<a href="http://www.facebook.com/twitter" rel="nofollow">Facebook</a>': 1, '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>': 26, '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>': 33, '<a href="http://www.twitter.com" rel="nofollow">Twitter for BlackBerry</a>': 2, '<a href="http://www.google.com/" rel="nofollow">Google</a>': 2, '<a href="http://twitter.com/#!/download/ipad" rel="nofollow">Twitter for iPad</a>': 6, '<a href="http://linkis.com" rel="nofollow">Linkis.com</a>': 2, '<a href="http://rutracker.org/forum/viewforum.php?f=93" rel="nofollow">newzlasz</a>': 2, '<a href="http://ifttt.com" rel="nofollow">IFTTT</a>': 1, '<a href="http://www.myplume.com/" rel="nofollow">Plume\xa0for\xa0Android</a>': 1}

# %%
# Define count_entries()
def count_entries(df,*args):
    """Return a dictionary with counts of
    occurrences as value for each key."""
    
    #Initialize an empty dictionary: cols_count
    cols_count = {}
    
    # Iterate over column names in args
    for col_name in args:
    
        # Extract column from DataFrame: col
        col = df[col_name]
    
        # Iterate over the column in DataFrame
        for entry in col:
    
            # If entry is in cols_count, add 1
            if entry in cols_count.keys():
                cols_count[entry] += 1
    
            # Else add the entry to cols_count, set the value to 1
            else:
                cols_count[entry] = 1

    # Return the cols_count dictionary
    return cols_count

# Call count_entries(): result1
result1 = count_entries(tweets_df,'lang')

# Call count_entries(): result2
result2 = count_entries(tweets_df,'lang','source')

# Print result1 and result2
print(result1)
print(result2)
# Out:
# {'en': 97, 'et': 1, 'und': 2}
# {'en': 97, 'et': 1, 'und': 2, '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>': 24, '<a href="http://www.facebook.com/twitter" rel="nofollow">Facebook</a>': 1, '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>': 26, '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>': 33, '<a href="http://www.twitter.com" rel="nofollow">Twitter for BlackBerry</a>': 2, '<a href="http://www.google.com/" rel="nofollow">Google</a>': 2, '<a href="http://twitter.com/#!/download/ipad" rel="nofollow">Twitter for iPad</a>': 6, '<a href="http://linkis.com" rel="nofollow">Linkis.com</a>': 2, '<a href="http://rutracker.org/forum/viewforum.php?f=93" rel="nofollow">newzlasz</a>': 2, '<a href="http://ifttt.com" rel="nofollow">IFTTT</a>': 1, '<a href="http://www.myplume.com/" rel="nofollow">Plume\xa0for\xa0Android</a>': 1}

# %%
raise_to_power = lambda x,y : x ** y
raise_to_power(2,3)
# Out:
# 8

# %%
nums = [48,9,21,1]
sqaure_all = map(lambda num: num ** 2,nums)
(sqaure_all)

# %%
list(sqaure_all)
# Out:
# [2304, 81, 441, 1]

# %% [markdown]
# - --------------------------------------------------------------------------
# - ## Introduction to Error Handling:-

# %%
float('hello')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-177-879c4bea9d62> in <module>()
# ----> 1 float('hello')
#
# ValueError: could not convert string to float: 'hello'

# %%
float(len('hello'))
# Out:
# 5.0

# %%
def sqrt(value):
    if type(value) == float: 
        new_value = value ** 2
        print( new_value)
    else :
        print(value,',value must be either int or float.')
(sqrt(4))
sqrt('Nikhil')
# Out:
# 4 ,value must be either int or float.
# Nikhil ,value must be either int or float.

# %%
def sqrt(value):
    if value <= 0:
        raise ValueError('value must be positive')
    else:
        try:
            return value ** 2
        except TypeError:
            print(value,',value must be either int or float')
print(sqrt(3))

sqrt(len('Nikhil'))
# Out:
# 9
# 36

# %%
print(sqrt(-123))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-205-defb3a4d5efd> in <module>()
# ----> 1 print(sqrt(-123))
#
# <ipython-input-204-d5cf85698c55> in sqrt(value)
#       1 def sqrt(value):
#       2     if value <= 0:
# ----> 3         raise ValueError('value must be positive')
#       4     else:
#       5         try:
#
# ValueError: value must be positive

# %%
# Define shout_echo
def shout_echo(word1, echo=1):
    """Concatenate echo copies of word1 and three
    exclamation marks at the end of the string."""

    # Initialize empty strings: echo_word, shout_words
    echo_word = ''
    shout_words=''

    # Add exception handling with try-except
    try:
        # Concatenate echo copies of word1 using *: echo_word
        echo_word = word1 * echo

        # Concatenate '!!!' to echo_word: shout_words
        shout_words = echo_word + '!!!'
    except:
        # Print error message
        print("word1 must be a string and echo must be an integer.")

    # Return shout_words
    return shout_words

# Call shout_echo
shout_echo("particle", echo="accelerator")
# Out:
# word1 must be a string and echo must be an integer.
# ''

# %% [markdown]
# Hi,<font color='orange'>Nikhil is my name </font> ,Thanks
