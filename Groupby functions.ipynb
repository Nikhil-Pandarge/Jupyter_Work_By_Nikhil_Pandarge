# %% [markdown]
# ## Groupby functions

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('movies_data.csv')
print(df)
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 0                R      Crime       142
# 1                R      Crime       175
# 2                R      Crime       200
# ...

# %%
df['genre'].value_counts()
# Out:
# Drama        278
# Comedy       156
# Action       136
# Crime        124
# Biography     77
# Adventure     75
# Animation     62
# Horror        29
# Mystery       16
# Western        9
# Sci-Fi         5
# Thriller       5
# Film-Noir      3
# Family         2
# History        1
# Fantasy        1
# Name: genre, dtype: int64

# %%
df.groupby('genre')

# %%
# Define a dictionary containing employee data
data1 = {'Name':['Jai', 'Anuj', 'Jai', 'Princi',
                 'Gaurav', 'Anuj', 'Princi', 'Abhi'],
        'Age':[27, 24, 22, 32,
               33, 36, 27, 32],
        'Address':['Nagpur', 'Kanpur', 'Allahabad', 'Kannuaj',
                   'Jaunpur', 'Kanpur', 'Allahabad', 'Aligarh'],
        'Qualification':['Msc', 'MA', 'MCA', 'Phd',
                         'B.Tech', 'B.com', 'Msc', 'MA']}
    
  
# Convert the dictionary into DataFrame 
df_data1 = pd.DataFrame(data1)
  
print(df_data1)
# Out:
#      Name  Age    Address Qualification
# 0     Jai   27     Nagpur           Msc
# 1    Anuj   24     Kanpur            MA
# 2     Jai   22  Allahabad           MCA
# 3  Princi   32    Kannuaj           Phd
# 4  Gaurav   33    Jaunpur        B.Tech
# 5    Anuj   36     Kanpur         B.com
# 6  Princi   27  Allahabad           Msc
# 7    Abhi   32    Aligarh            MA

# %%
df.groupby("Age").get_group(27)
# Out:
#      Name  Age    Address Qualification
# 0     Jai   27     Nagpur           Msc
# 6  Princi   27  Allahabad           Msc

# %%
df.groupby('genre').first()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# d:\17L plus\Daily Teching Notes\07_05_Pandas_Apply_Grouby\Groupby functions.ipynb Cell 8' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/d%3A/17L%20plus/Daily%20Teching%20Notes/07_05_Pandas_Apply_Grouby/Groupby%20functions.ipynb#ch0000005?line=0'>1</a> df.groupby('genre').first()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\pandas\core\frame.py:7712, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    7707 axis = self._get_axis_number(axis)
#    7709 # https://github.com/python/mypy/issues/7642
#    7710 # error: Argument "squeeze" to "DataFrameGroupBy" has incompatible type
#    7711 # "Union[bool, NoDefault]"; expected "bool"
# -> 7712 return DataFrameGroupBy(
# ...

# %%
df.groupby('genre').last()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# d:\17L plus\Daily Teching Notes\07_05_Pandas_Apply_Grouby\Groupby functions.ipynb Cell 9' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/d%3A/17L%20plus/Daily%20Teching%20Notes/07_05_Pandas_Apply_Grouby/Groupby%20functions.ipynb#ch0000109?line=0'>1</a> df.groupby('genre').last()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\pandas\core\frame.py:7712, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    7707 axis = self._get_axis_number(axis)
#    7709 # https://github.com/python/mypy/issues/7642
#    7710 # error: Argument "squeeze" to "DataFrameGroupBy" has incompatible type
#    7711 # "Union[bool, NoDefault]"; expected "bool"
# -> 7712 return DataFrameGroupBy(
# ...

# %%
df.groupby('genre').get_group('Action')
# Out:
#      star_rating                                            title  \
# 3            9.0                                  The Dark Knight
# 11           8.8                                        Inception
# 12           8.8   Star Wars: Episode V - The Empire Strikes Back
# 19           8.7                                        Star Wars
# 20           8.7                                       The Matrix
# ..           ...                                              ...
# 918          7.5                                   Running Scared
# 954          7.4                                            X-Men
# 963          7.4                                  La Femme Nikita
# 967          7.4                                         The Rock
# 976          7.4  Master and Commander: The Far Side of the World
#
#     content_rating   genre  duration  \
# 3            PG-13  Action       152
# 11           PG-13  Action       148
# 12              PG  Action       124
# ...

# %%
df[df['genre']=='Action']
# Out:
#      star_rating                                            title  \
# 3            9.0                                  The Dark Knight
# 11           8.8                                        Inception
# 12           8.8   Star Wars: Episode V - The Empire Strikes Back
# 19           8.7                                        Star Wars
# 20           8.7                                       The Matrix
# ..           ...                                              ...
# 918          7.5                                   Running Scared
# 954          7.4                                            X-Men
# 963          7.4                                  La Femme Nikita
# 967          7.4                                         The Rock
# 976          7.4  Master and Commander: The Far Side of the World
#
#     content_rating   genre  duration  \
# 3            PG-13  Action       152
# 11           PG-13  Action       148
# 12              PG  Action       124
# ...

# %%
crime_df = df.groupby('genre').get_group('Crime')
crime_df
# Out:
#      star_rating                     title content_rating  genre  duration  \
# 0            9.3  The Shawshank Redemption              R  Crime       142
# 1            9.2             The Godfather              R  Crime       175
# 2            9.1    The Godfather: Part II              R  Crime       200
# 4            8.9              Pulp Fiction              R  Crime       154
# 21           8.7               City of God              R  Crime       130
# ..           ...                       ...            ...    ...       ...
# 927          7.5                     Brick              R  Crime       110
# 931          7.4              Mean Streets              R  Crime       112
# 950          7.4                     Bound              R  Crime       108
# 969          7.4       Law Abiding Citizen              R  Crime       109
# 978          7.4               Wall Street              R  Crime       126
#
#                                            actors_list
# ...

# %%
df['genre'].value_counts()
# Out:
# Drama        278
# Comedy       156
# Action       136
# Crime        124
# Biography     77
# Adventure     75
# Animation     62
# Horror        29
# Mystery       16
# Western        9
# Sci-Fi         5
# Thriller       5
# Film-Noir      3
# Family         2
# History        1
# Fantasy        1
# Name: genre, dtype: int64

# %%
df.groupby('genre').groups
# Out:
# {'Action': [3, 11, 12, 19, 20, 36, 37, 43, 44, 45, 75, 80, 82, 96, 100, 113, 118, 123, 129, 135, 138, 152, 163, 173, 177, 194, 196, 198, 235, 239, 240, 248, 261, 268, 276, 281, 296, 301, 312, 327, 349, 354, 366, 380, 385, 388, 391, 401, 403, 409, 411, 420, 433, 434, 437, 440, 452, 455, 469, 470, 488, 491, 502, 509, 515, 517, 529, 531, 532, 533, 534, 539, 552, 563, 567, 568, 570, 573, 581, 586, 591, 598, 610, 613, 619, 623, 633, 649, 653, 661, 671, 675, 683, 684, 685, 686, 691, 699, 701, 707, ...], 'Adventure': [7, 10, 14, 15, 54, 68, 71, 85, 101, 114, 120, 128, 133, 137, 140, 142, 164, 179, 204, 206, 214, 222, 224, 245, 271, 299, 309, 310, 328, 333, 336, 339, 359, 362, 368, 376, 393, 419, 424, 429, 445, 454, 479, 510, 520, 522, 537, 551, 555, 564, 576, 605, 629, 642, 658, 662, 698, 727, 754, 758, 794, 814, 852, 891, 898, 900, 909, 911, 932, 935, 936, 937, 943, 953, 975], 'Animation': [30, 55, 61, 64, 69, 81, 117, 126, 131, 147, 160, 167, 192, 193, 241, 256, 277, 294, 303, 305, 308, 3
# ...

# %%
df
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 0                R      Crime       142
# 1                R      Crime       175
# 2                R      Crime       200
# ...

# %%
df.groupby('genre').groups.keys()
# Out:
# dict_keys(['Action', 'Adventure', 'Animation', 'Biography', 'Comedy', 'Crime', 'Drama', 'Family', 'Fantasy', 'Film-Noir', 'History', 'Horror', 'Mystery', 'Sci-Fi', 'Thriller', 'Western'])

# %%
df.groupby(['genre','content_rating']).get_group(('Action','PG-13'))
# Out:
#      star_rating                                            title  \
# 3            9.0                                  The Dark Knight
# 11           8.8                                        Inception
# 43           8.5                            The Dark Knight Rises
# 113          8.3                                    Batman Begins
# 118          8.3               Indiana Jones and the Last Crusade
# 177          8.2                                     The Avengers
# 196          8.1                          Guardians of the Galaxy
# 240          8.1                             The Bourne Ultimatum
# 248          8.1                       X-Men: Days of Future Past
# 301          8.0                                        Furious 7
# 312          8.0                                        Star Trek
# 366          8.0                                         Serenity
# 380          8.0                                    Casino Royale
# ...

# %%
df['content_rating'].unique()
# Out:
# array(['R', 'PG-13', 'NOT RATED', 'PG', 'UNRATED', 'APPROVED', 'PASSED',
#        'G', 'X', nan, 'TV-MA', 'GP', 'NC-17'], dtype=object)

# %%
df.groupby(['genre','content_rating']).get_group(('Crime','PG'))
# Out:
#      star_rating                  title content_rating  genre  duration  \
# 154          8.2         Cool Hand Luke             PG  Crime       126
# 171          8.2      Dial M for Murder             PG  Crime       105
# 200          8.1            Le Samourai             PG  Crime       101
# 297          8.0                   Rope             PG  Crime        80
# 425          7.9               Badlands             PG  Crime        94
# 495          7.8  The Day of the Jackal             PG  Crime       143
#
#                                            actors_list
# 154  [u'Paul Newman', u'George Kennedy', u'Strother...
# 171  [u'Ray Milland', u'Grace Kelly', u'Robert Cumm...
# 200  [u'Alain Delon', u'Nathalie Delon', u'Fran\xe7...
# 297  [u'James Stewart', u'John Dall', u'Farley Gran...
# 425  [u'Martin Sheen', u'Sissy Spacek', u'Warren Oa...
# 495  [u'Edward Fox', u'Terence Alexander', u'Michel...

# %%
df[(df['genre'] == 'Crime') & (df['content_rating']=='PG')]
# Out:
#      star_rating                  title content_rating  genre  duration  \
# 154          8.2         Cool Hand Luke             PG  Crime       126
# 171          8.2      Dial M for Murder             PG  Crime       105
# 200          8.1            Le Samourai             PG  Crime       101
# 297          8.0                   Rope             PG  Crime        80
# 425          7.9               Badlands             PG  Crime        94
# 495          7.8  The Day of the Jackal             PG  Crime       143
#
#                                            actors_list
# 154  [u'Paul Newman', u'George Kennedy', u'Strother...
# 171  [u'Ray Milland', u'Grace Kelly', u'Robert Cumm...
# 200  [u'Alain Delon', u'Nathalie Delon', u'Fran\xe7...
# 297  [u'James Stewart', u'John Dall', u'Farley Gran...
# 425  [u'Martin Sheen', u'Sissy Spacek', u'Warren Oa...
# 495  [u'Edward Fox', u'Terence Alexander', u'Michel...

# %%
df.groupby(['genre','content_rating']).get_group(('Action','PG-13')).sort_values('duration')
# Out:
#      star_rating                                            title  \
# 455          7.9                                            Taken
# 403          7.9                                       Ying xiong
# 954          7.4                                            X-Men
# 653          7.7                                         Fearless
# 787          7.6                   Rise of the Planet of the Apes
# 567          7.8                             The Bourne Supremacy
# 812          7.6                         Star Trek: First Contact
# 856          7.5                      Scott Pilgrim vs. the World
# 391          8.0                                 Edge of Tomorrow
# 240          8.1                             The Bourne Ultimatum
# 366          8.0                                         Serenity
# 809          7.6                          House of Flying Daggers
# 411          7.9                              The Bourne Identity
# ...

# %%
df.groupby(['genre','content_rating']).get_group(('Action','PG-13'))[['genre', 'title', 'content_rating']]
# Out:
#       genre                                            title content_rating
# 3    Action                                  The Dark Knight          PG-13
# 11   Action                                        Inception          PG-13
# 43   Action                            The Dark Knight Rises          PG-13
# 113  Action                                    Batman Begins          PG-13
# 118  Action               Indiana Jones and the Last Crusade          PG-13
# 177  Action                                     The Avengers          PG-13
# 196  Action                          Guardians of the Galaxy          PG-13
# 240  Action                             The Bourne Ultimatum          PG-13
# 248  Action                       X-Men: Days of Future Past          PG-13
# 301  Action                                        Furious 7          PG-13
# 312  Action                                        Star Trek          PG-13
# ...

# %%
df.loc[(df['genre'] == 'Crime') & (df['content_rating']=='PG')]
# Out:
#      star_rating                  title content_rating  genre  duration  \
# 154          8.2         Cool Hand Luke             PG  Crime       126
# 171          8.2      Dial M for Murder             PG  Crime       105
# 200          8.1            Le Samourai             PG  Crime       101
# 297          8.0                   Rope             PG  Crime        80
# 425          7.9               Badlands             PG  Crime        94
# 495          7.8  The Day of the Jackal             PG  Crime       143
#
#                                            actors_list
# 154  [u'Paul Newman', u'George Kennedy', u'Strother...
# 171  [u'Ray Milland', u'Grace Kelly', u'Robert Cumm...
# 200  [u'Alain Delon', u'Nathalie Delon', u'Fran\xe7...
# 297  [u'James Stewart', u'John Dall', u'Farley Gran...
# 425  [u'Martin Sheen', u'Sissy Spacek', u'Warren Oa...
# 495  [u'Edward Fox', u'Terence Alexander', u'Michel...

# %%
df[(df['genre'] == 'Drama') & (df['content_rating']=='PG') & (df['duration'] >=120)]
# Out:
#      star_rating                               title content_rating  genre  \
# 47           8.5                    Taare Zameen Par             PG  Drama
# 221          8.1                             Solaris             PG  Drama
# 267          8.1                                Jaws             PG  Drama
# 284          8.1            A Streetcar Named Desire             PG  Drama
# 342          8.0                  Dead Poets Society             PG  Drama
# 404          7.9              The Remains of the Day             PG  Drama
# 448          7.9                             Cabaret             PG  Drama
# 504          7.8                   Empire of the Sun             PG  Drama
# 525          7.8                   Pride & Prejudice             PG  Drama
# 634          7.7  Close Encounters of the Third Kind             PG  Drama
# 645          7.7               Sense and Sensibility             PG  Drama
# ...

# %%
df[(df['duration'] >=120) & (df['duration']<=180)]
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# 6            8.9                   The Good, the Bad and the Ugly
# ..           ...                                              ...
# 967          7.4                                         The Rock
# 968          7.4                              The English Patient
# 973          7.4                            The Cider House Rules
# 976          7.4  Master and Commander: The Far Side of the World
# 978          7.4                                      Wall Street
#
#     content_rating    genre  duration  \
# 0                R    Crime       142
# 1                R    Crime       175
# 3            PG-13   Action       152
# ...

# %%
df[df['duration'].between(120,180)]
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# 6            8.9                   The Good, the Bad and the Ugly
# ..           ...                                              ...
# 967          7.4                                         The Rock
# 968          7.4                              The English Patient
# 973          7.4                            The Cider House Rules
# 976          7.4  Master and Commander: The Far Side of the World
# 978          7.4                                      Wall Street
#
#     content_rating    genre  duration  \
# 0                R    Crime       142
# 1                R    Crime       175
# 3            PG-13   Action       152
# ...

# %%
df['duration'].between(120,180)
# Out:
# 0       True
# 1       True
# 2      False
# 3       True
# 4       True
#        ...
# 974    False
# 975    False
# 976     True
# 977    False
# 978     True
# Name: duration, Length: 979, dtype: bool

# %%
df[((df['genre'] == 'Drama') | (df['genre'] == 'Action')) & (df['content_rating']=='PG') & (df['duration'] >=120)]
# Out:
#      star_rating                                           title  \
# 12           8.8  Star Wars: Episode V - The Empire Strikes Back
# 19           8.7                                       Star Wars
# 47           8.5                                Taare Zameen Par
# 80           8.4      Star Wars: Episode VI - Return of the Jedi
# 221          8.1                                         Solaris
# 267          8.1                                            Jaws
# 284          8.1                        A Streetcar Named Desire
# 342          8.0                              Dead Poets Society
# 404          7.9                          The Remains of the Day
# 420          7.9                       The Man Who Would Be King
# 448          7.9                                         Cabaret
# 504          7.8                               Empire of the Sun
# 525          7.8                               Pride & Prejudice
# ...

# %%
df['content_rating'].unique()
# Out:
# array(['R', 'PG-13', 'NOT RATED', 'PG', 'UNRATED', 'APPROVED', 'PASSED',
#        'G', 'X', nan, 'TV-MA', 'GP', 'NC-17'], dtype=object)

# %%
df[(df['content_rating'] == 'APPROVED') & ((df['genre']=='Comedy') | (df['star_rating'] <8))]
# Out:
#      star_rating                            title content_rating      genre  \
# 52           8.5               The Great Dictator       APPROVED     Comedy
# 94           8.4              Singin' in the Rain       APPROVED     Comedy
# 103          8.3                    The Apartment       APPROVED     Comedy
# 285          8.1                 Bringing Up Baby       APPROVED     Comedy
# 287          8.1                  His Girl Friday       APPROVED     Comedy
# 298          8.0                     The Graduate       APPROVED     Comedy
# 410          7.9                 Bonnie and Clyde       APPROVED  Biography
# 444          7.9                     My Fair Lady       APPROVED      Drama
# 445          7.9             The Ten Commandments       APPROVED  Adventure
# 451          7.9           Miracle on 34th Street       APPROVED     Comedy
# 484          7.8    The Day the Earth Stood Still       APPROVED     Sci-Fi
# ...

# %%
df.groupby(['genre','content_rating']).get_group(('PG' , 'Crime'))  # we've to follow the sequence
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-37-adcc8a9347b6> in <module>
# ----> 1 df.groupby(['genre','content_rating']).get_group(('PG' , 'Crime'))
#
# ~\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in get_group(self, name, obj)
#     843         inds = self._get_index(name)
#     844         if not len(inds):
# --> 845             raise KeyError(name)
#     846
#     847         return obj._take_with_is_copy(inds, axis=self.axis)
#
# KeyError: ('PG', 'Crime')

# %%
action_PG13 = df.groupby(['genre','content_rating']).get_group(('Action','PG-13'))
action_PG13
# Out:
#      star_rating                                            title  \
# 3            9.0                                  The Dark Knight
# 11           8.8                                        Inception
# 43           8.5                            The Dark Knight Rises
# 113          8.3                                    Batman Begins
# 118          8.3               Indiana Jones and the Last Crusade
# 177          8.2                                     The Avengers
# 196          8.1                          Guardians of the Galaxy
# 240          8.1                             The Bourne Ultimatum
# 248          8.1                       X-Men: Days of Future Past
# 301          8.0                                        Furious 7
# 312          8.0                                        Star Trek
# 366          8.0                                         Serenity
# 380          8.0                                    Casino Royale
# ...

# %%
action_PG13[['genre', 'title', 'content_rating']]
# Out:
#       genre                                            title content_rating
# 3    Action                                  The Dark Knight          PG-13
# 11   Action                                        Inception          PG-13
# 43   Action                            The Dark Knight Rises          PG-13
# 113  Action                                    Batman Begins          PG-13
# 118  Action               Indiana Jones and the Last Crusade          PG-13
# 177  Action                                     The Avengers          PG-13
# 196  Action                          Guardians of the Galaxy          PG-13
# 240  Action                             The Bourne Ultimatum          PG-13
# 248  Action                       X-Men: Days of Future Past          PG-13
# 301  Action                                        Furious 7          PG-13
# 312  Action                                        Star Trek          PG-13
# ...

# %%
df.groupby(['genre','content_rating']).get_group(['Action','PG-13'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-42-95a61c75c711> in <module>
# ----> 1 df.groupby(['genre','content_rating']).get_group(['Action','PG-13'])
#
# ~\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in get_group(self, name, obj)
#     841             obj = self._selected_obj
#     842
# --> 843         inds = self._get_index(name)
#     844         if not len(inds):
#     845             raise KeyError(name)
#
# ~\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in _get_index(self, name)
#     670         Safe get index, translate keys for datelike to underlying repr.
#     671         """
# --> 672         return self._get_indices([name])[0]
#     673
#     674     @final
#
# ~\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in _get_indices(self, names)
#     643             if not isinstance(name_sample, tuple):
# ...

# %%
df
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 0                R      Crime       142
# 1                R      Crime       175
# 2                R      Crime       200
# ...

# %% [markdown]
# ## mean

# %%
df.groupby('genre')['star_rating'].mean()
# Out:
# genre
# Action       7.884559
# Adventure    7.933333
# Animation    7.914516
# Biography    7.862338
# Comedy       7.822436
# Crime        7.916935
# Drama        7.902518
# Family       7.850000
# Fantasy      7.700000
# Film-Noir    8.033333
# History      8.000000
# Horror       7.806897
# Mystery      7.975000
# Sci-Fi       7.920000
# Thriller     7.680000
# Western      8.255556
# Name: star_rating, dtype: float64

# %%
action = df.groupby('genre').get_group('Action')
action['star_rating'].mean()
# Out:
# 7.88455882352942

# %%
df.groupby('genre')['duration'].mean()
# Out:
# genre
# Action       126.485294
# Adventure    134.840000
# Animation     96.596774
# Biography    131.844156
# Comedy       107.602564
# Crime        122.298387
# Drama        126.539568
# Family       107.500000
# Fantasy      112.000000
# Film-Noir     97.333333
# History       66.000000
# Horror       102.517241
# Mystery      115.625000
# Sci-Fi       109.000000
# Thriller     114.200000
# Western      136.666667
# Name: duration, dtype: float64

# %%
df.groupby('genre')['duration'].max()
# Out:
# genre
# Action       205
# Adventure    224
# Animation    134
# Biography    202
# Comedy       187
# Crime        229
# Drama        242
# Family       115
# Fantasy      112
# Film-Noir    111
# History       66
# Horror       146
# Mystery      160
# Sci-Fi       132
# Thriller     120
# Western      175
# Name: duration, dtype: int64

# %%
df.groupby('genre')['duration'].min()
# Out:
# genre
# Action        80
# Adventure     89
# Animation     75
# Biography     85
# Comedy        68
# Crime         67
# Drama         64
# Family       100
# Fantasy      112
# Film-Noir     88
# History       66
# Horror        70
# Mystery       69
# Sci-Fi        91
# Thriller     107
# Western       85
# Name: duration, dtype: int64

# %%
df['duration'].max()
# Out:
# 242

# %%
df.groupby('genre')('duration').min()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-53-142cfd0c9809> in <module>
# ----> 1 df.groupby('genre')('duration').min()
#
# TypeError: 'DataFrameGroupBy' object is not callable

# %%
dict1 = {'Val1': np.random.randint(1,31, size = 30)}
df1 = pd.DataFrame(dict1)
df1['Month'] = 7
df1['Year'] = 2022
df1
# Out:
#     Val1  Month  Year
# 0     27      7  2022
# 1     12      7  2022
# 2      4      7  2022
# 3      6      7  2022
# 4     25      7  2022
# 5      8      7  2022
# 6     28      7  2022
# 7     25      7  2022
# 8     25      7  2022
# 9     17      7  2022
# 10    13      7  2022
# 11    30      7  2022
# 12    24      7  2022
# 13    29      7  2022
# 14    19      7  2022
# 15     5      7  2022
# 16     5      7  2022
# 17    26      7  2022
# 18     8      7  2022
# 19    14      7  2022
# 20    17      7  2022
# 21     3      7  2022
# 22     6      7  2022
# 23    11      7  2022
# 24    18      7  2022
# 25    17      7  2022
# 26    24      7  2022
# 27    12      7  2022
# 28    11      7  2022
# 29    13      7  2022

# %%
df1.dtypes
# Out:
# Val1     int32
# Month    int64
# Year     int64
# dtype: object

# %%
df1['Date'] = df1['Val1'].astype(str) + '-' + df1['Month'].astype(str) + '-' + df1['Year'].astype(str)
df1
# Out:
#     Val1  Month  Year       Date
# 0     27      7  2022  27-7-2022
# 1     12      7  2022  12-7-2022
# 2      4      7  2022   4-7-2022
# 3      6      7  2022   6-7-2022
# 4     25      7  2022  25-7-2022
# 5      8      7  2022   8-7-2022
# 6     28      7  2022  28-7-2022
# 7     25      7  2022  25-7-2022
# 8     25      7  2022  25-7-2022
# 9     17      7  2022  17-7-2022
# 10    13      7  2022  13-7-2022
# 11    30      7  2022  30-7-2022
# 12    24      7  2022  24-7-2022
# 13    29      7  2022  29-7-2022
# 14    19      7  2022  19-7-2022
# 15     5      7  2022   5-7-2022
# 16     5      7  2022   5-7-2022
# 17    26      7  2022  26-7-2022
# 18     8      7  2022   8-7-2022
# 19    14      7  2022  14-7-2022
# 20    17      7  2022  17-7-2022
# 21     3      7  2022   3-7-2022
# 22     6      7  2022   6-7-2022
# 23    11      7  2022  11-7-2022
# 24    18      7  2022  18-7-2022
# 25    17      7  2022  17-7-2022
# 26    24      7  2022  24-7-2022
# ...

# %%
df1['Date'].nunique()
# Out:
# 19

# %%
df1.groupby('Date')

# %%
chetan   45678 453214 male 6587 12-07-2020

# %%
df1['Date'].value_counts()
# Out:
# 25-7-2022    3
# 17-7-2022    3
# 8-7-2022     2
# 11-7-2022    2
# 6-7-2022     2
# 12-7-2022    2
# 5-7-2022     2
# 24-7-2022    2
# 13-7-2022    2
# 18-7-2022    1
# 29-7-2022    1
# 4-7-2022     1
# 26-7-2022    1
# 27-7-2022    1
# 19-7-2022    1
# 3-7-2022     1
# 28-7-2022    1
# 14-7-2022    1
# 30-7-2022    1
# Name: Date, dtype: int64

# %%
df1.groupby('Date').size().to_frame('No_of_appln').reset_index()
# Out:
#          Date  No_of_appln
# 0   11-7-2022            2
# 1   12-7-2022            2
# 2   13-7-2022            2
# 3   14-7-2022            1
# 4   17-7-2022            3
# 5   18-7-2022            1
# 6   19-7-2022            1
# 7   24-7-2022            2
# 8   25-7-2022            3
# 9   26-7-2022            1
# 10  27-7-2022            1
# 11  28-7-2022            1
# 12  29-7-2022            1
# 13   3-7-2022            1
# 14  30-7-2022            1
# 15   4-7-2022            1
# 16   5-7-2022            2
# 17   6-7-2022            2
# 18   8-7-2022            2

# %%
df1.groupby('Date').count()
# Out:
#            Val1  Month  Year
# Date
# 11-7-2022     2      2     2
# 12-7-2022     2      2     2
# 13-7-2022     2      2     2
# 14-7-2022     1      1     1
# 17-7-2022     3      3     3
# 18-7-2022     1      1     1
# 19-7-2022     1      1     1
# 24-7-2022     2      2     2
# 25-7-2022     3      3     3
# 26-7-2022     1      1     1
# 27-7-2022     1      1     1
# 28-7-2022     1      1     1
# 29-7-2022     1      1     1
# 3-7-2022      1      1     1
# 30-7-2022     1      1     1
# 4-7-2022      1      1     1
# 5-7-2022      2      2     2
# 6-7-2022      2      2     2
# 8-7-2022      2      2     2

# %%
BFSI >>>

# %%
Github >> storage of scripts(codes)

Databricks >> cloud platfrom(server) >> Azure >> pyspark(to_pandas) >> DBFS
AWS >> Sagemaker

Pandas 
Pyspark   select * from loan_finacle
Dask

# %% [markdown]
# ![image.png](attachment:image.png)
